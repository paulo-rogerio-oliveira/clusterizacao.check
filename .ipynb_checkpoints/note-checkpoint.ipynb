# %%
#Resposta questão 1.1
##Versão Python 3.9.20
import sys
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Resposta questão 1.2
##Ambiente do projeto -> Anaconda
from PIL import Image
import matplotlib.pyplot as plt

# print screen of my monitor
image_path = 'screen.png'

# Open the image file
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()#Resposta questão 1
##Versão Python -> 3.12.7
##Ambiente do projeto -> Anaconda
from PIL import Image
import matplotlib.pyplot as plt

# print screen of my monitor
image_path = 'screen.png'

# Open the image file
#image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide the axis
plt.show()

# %%
#Resposta questão 2 - Escolha base de dados
## https://www.kaggle.com/datasets/lucasdasilvadantas/brazils-energy-consumption/data
## Base de dados escolhida por conta da curiosidade de saber se é possível criar grupos que ajudem a 
## compreender a dinâmica regional do consumo elétrico os padrões de consumo energético dos estados do Brasil.

file_path = 'data\\brazil_data.xlsx'


df = pd.read_excel(file_path)

# Display the first few rows of the dataframe
display(df)
# Out:
#             Data TipoConsumidor                 Sistema  UF  \
# 0       20140101         Cativo  Sudeste / Centro-Oeste  RO
# 1       20140201         Cativo  Sudeste / Centro-Oeste  RO
# 2       20140301         Cativo  Sudeste / Centro-Oeste  RO
# 3       20140401         Cativo  Sudeste / Centro-Oeste  RO
# 4       20140501         Cativo  Sudeste / Centro-Oeste  RO
# ...          ...            ...                     ...  ..
# 285494  20210801         Cativo  Sudeste / Centro-Oeste  DF
# 285495  20210901         Cativo  Sudeste / Centro-Oeste  DF
# 285496  20211001         Cativo  Sudeste / Centro-Oeste  DF
# 285497  20211101         Cativo  Sudeste / Centro-Oeste  DF
# 285498  20211201         Cativo  Sudeste / Centro-Oeste  DF
#
#        Setor Econômico - N1                Setor Econômico - N2  \
# 0               Residencial  Convencional (Excepto Baixa Renda)
# 1               Residencial  Convencional (Excepto Baixa Renda)
# 2               Residencial  Convencional (Excepto Baixa Renda)
# 3               Residencial  Convencional (Excepto Baixa Renda)
# 4               Residencial  Convencional (Excepto Baixa Renda)
# ...                     ...                                 ...
# 285494      Consumo Próprio                   Outras Atividades
# 285495      Consumo Próprio                   Outras Atividades
# 285496      Consumo Próprio                   Outras Atividades
# 285497      Consumo Próprio                   Outras Atividades
# 285498      Consumo Próprio                   Outras Atividades
#
#        Setor Econômico - N3 Tipo Tensão - N1   Tipo Tensão - N2  \
# 0                     TOTAL  A - Alta Tensão              TOTAL
# 1                     TOTAL  A - Alta Tensão              TOTAL
# 2                     TOTAL  A - Alta Tensão              TOTAL
# 3                     TOTAL  A - Alta Tensão              TOTAL
# 4                     TOTAL  A - Alta Tensão              TOTAL
# ...                     ...              ...                ...
# 285494                TOTAL  A - Alta Tensão  A-4 - 2,3 a 25 kV
# 285495                TOTAL  A - Alta Tensão  A-4 - 2,3 a 25 kV
# 285496                TOTAL  A - Alta Tensão  A-4 - 2,3 a 25 kV
# 285497                TOTAL  A - Alta Tensão  A-4 - 2,3 a 25 kV
# 285498                TOTAL  A - Alta Tensão  A-4 - 2,3 a 25 kV
#
#        Tipo Tensão - N3 Faixa de Consumo N1 Faixa de Consumo N2  Consumidores  \
# 0                 TOTAL         Alta Tensão         Alta Tensão           1.0
# 1                 TOTAL         Alta Tensão         Alta Tensão           1.0
# 2                 TOTAL         Alta Tensão         Alta Tensão           1.0
# 3                 TOTAL         Alta Tensão         Alta Tensão           1.0
# 4                 TOTAL         Alta Tensão         Alta Tensão           1.0
# ...                 ...                 ...                 ...           ...
# 285494            TOTAL       Não Aplicável       Não Aplicável           1.0
# 285495            TOTAL       Não Aplicável       Não Aplicável           1.0
# 285496            TOTAL       Não Aplicável       Não Aplicável           1.0
# 285497            TOTAL       Não Aplicável       Não Aplicável           1.0
# 285498            TOTAL       Não Aplicável       Não Aplicável           1.0
#
#         Consumo
# 0           8.0
# 1           8.0
# 2           9.0
# 3          10.0
# 4           9.0
# ...         ...
# 285494      NaN
# 285495      NaN
# 285496      NaN
# 285497      NaN
# 285498      NaN
#
# [285499 rows x 14 columns]

# %%
#Resposta questão 2 - Faixa de valores e o que deve ser feito
plt.figure(figsize=(15,8))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.title("Boxplots")
plt.show()

# %%
## Com base nos gráficos. Vai ser necessário tratar o null, utilizar a UF como label. Retirar o campos texto que não serão utilizados por não ser relevante
## para o objetivo. 
## também será necessário substituir a vírgula por ponto para então normalizar

# %%
# Ajustando nulo e valores negativos
df['Consumidores'].fillna(0)

# Ajustando nulo e valores negativos
df['Consumo'].fillna(0)

# Remove negative values in 'Consumidores' and 'Consumo' as they likely indicate errors
df = df[(df['Consumidores'] >= 0) & (df['Consumo'] >= 0)]

# Verify that no negative values remain in these columns
cleaned_summary_stats = df[['Consumidores', 'Consumo']].describe()
cleaned_summary_stats

# Convertendo a coluna 'Consumo' de string para float (substituindo vírgula por ponto)
df['Consumo'] = df['Consumo'].astype(str).str.replace(",", ".").astype(float)

# Criando variáveis dummy para 'TipoConsumidor' e 'Sistema'
df_agg = pd.get_dummies(df, columns=['TipoConsumidor', 'Sistema', 'UF'])

# Removendo colunas que não serão usadas no cluster (por exemplo, 'UF' e 'Data')
df_agg = df_agg.drop(['Data','Setor Econômico - N1','Setor Econômico - N2',
                      'Setor Econômico - N3','Tipo Tensão - N1','Tipo Tensão - N2',
                      'Tipo Tensão - N3','Faixa de Consumo N1','Faixa de Consumo N2'], axis=1)
print(df_agg.dtypes)


display(df_agg.head())
# Out:
# Consumidores                      float64
# Consumo                           float64
# TipoConsumidor_Cativo                bool
# TipoConsumidor_Livre                 bool
# Sistema_Nordeste                     bool
# Sistema_Norte Interligado            bool
# Sistema_Sistemas Isolados            bool
# Sistema_Sudeste / Centro-Oeste       bool
# Sistema_Sul                          bool
# UF_AC                                bool
# UF_AL                                bool
# UF_AM                                bool
# UF_AP                                bool
# UF_BA                                bool
# UF_CE                                bool
# UF_DF                                bool
# UF_ES                                bool
# UF_GO                                bool
# UF_MA                                bool
# UF_MG                                bool
# UF_MS                                bool
# UF_MT                                bool
# UF_PA                                bool
# UF_PB                                bool
# UF_PE                                bool
# UF_PI                                bool
# UF_PR                                bool
# UF_RJ                                bool
# UF_RN                                bool
# UF_RO                                bool
# UF_RR                                bool
# UF_RS                                bool
# UF_SC                                bool
# UF_SE                                bool
# UF_SP                                bool
# UF_TO                                bool
# dtype: object
#    Consumidores  Consumo  TipoConsumidor_Cativo  TipoConsumidor_Livre  \
# 0           1.0      8.0                   True                 False
# 1           1.0      8.0                   True                 False
# 2           1.0      9.0                   True                 False
# 3           1.0     10.0                   True                 False
# 4           1.0      9.0                   True                 False
#
#    Sistema_Nordeste  Sistema_Norte Interligado  Sistema_Sistemas Isolados  \
# 0             False                      False                      False
# 1             False                      False                      False
# 2             False                      False                      False
# 3             False                      False                      False
# 4             False                      False                      False
#
#    Sistema_Sudeste / Centro-Oeste  Sistema_Sul  UF_AC  ...  UF_PR  UF_RJ  \
# 0                            True        False  False  ...  False  False
# 1                            True        False  False  ...  False  False
# 2                            True        False  False  ...  False  False
# 3                            True        False  False  ...  False  False
# 4                            True        False  False  ...  False  False
#
#    UF_RN  UF_RO  UF_RR  UF_RS  UF_SC  UF_SE  UF_SP  UF_TO
# 0  False   True  False  False  False  False  False  False
# 1  False   True  False  False  False  False  False  False
# 2  False   True  False  False  False  False  False  False
# 3  False   True  False  False  False  False  False  False
# 4  False   True  False  False  False  False  False  False
#
# [5 rows x 36 columns]

# %%
display(df_agg.head())
# 2. Normalizar as variáveis
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_agg)
display(X_scaled)
# Out:
#    Consumidores  Consumo  TipoConsumidor_Cativo  TipoConsumidor_Livre  \
# 0           1.0      8.0                   True                 False
# 1           1.0      8.0                   True                 False
# 2           1.0      9.0                   True                 False
# 3           1.0     10.0                   True                 False
# 4           1.0      9.0                   True                 False
#
#    Sistema_Nordeste  Sistema_Norte Interligado  Sistema_Sistemas Isolados  \
# 0             False                      False                      False
# 1             False                      False                      False
# 2             False                      False                      False
# 3             False                      False                      False
# 4             False                      False                      False
#
#    Sistema_Sudeste / Centro-Oeste  Sistema_Sul  UF_AC  ...  UF_PR  UF_RJ  \
# 0                            True        False  False  ...  False  False
# 1                            True        False  False  ...  False  False
# 2                            True        False  False  ...  False  False
# 3                            True        False  False  ...  False  False
# 4                            True        False  False  ...  False  False
#
#    UF_RN  UF_RO  UF_RR  UF_RS  UF_SC  UF_SE  UF_SP  UF_TO
# 0  False   True  False  False  False  False  False  False
# 1  False   True  False  False  False  False  False  False
# 2  False   True  False  False  False  False  False  False
# 3  False   True  False  False  False  False  False  False
# 4  False   True  False  False  False  False  False  False
#
# [5 rows x 36 columns]
# array([[-0.17504771, -0.23544552,  0.35674255, ..., -0.18215605,
#         -0.22551987, -0.18258775],
#        [-0.17504771, -0.23544552,  0.35674255, ..., -0.18215605,
#         -0.22551987, -0.18258775],
#        [-0.17504771, -0.23543231,  0.35674255, ..., -0.18215605,
#         -0.22551987, -0.18258775],
#        ...,
#        [-0.17504771, -0.23532659,  0.35674255, ..., -0.18215605,
#         -0.22551987, -0.18258775],
#        [-0.17504299, -0.23548516,  0.35674255, ..., -0.18215605,
#         -0.22551987, -0.18258775],
#        [-0.17504299, -0.23536623,  0.35674255, ..., -0.18215605,
#         -0.22551987, -0.18258775]])

# %%
from sklearn.metrics import silhouette_score
# 3. Encontrar o número ótimo de clusters para K-Médias usando índice de silhueta
range_n_clusters = range(4, 21, 3)  # Testar de 2 até 10 clusters, por exemplo
best_k = None
best_silhouette = -1
silhouette_scores = []

for k in range_n_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(X_scaled)
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)
    print(f"K={k}, Silhueta={silhouette_avg}")
    if silhouette_avg > best_silhouette:
        best_silhouette = silhouette_avg
        best_k = k

print(f"Melhor K para K-Médias: {best_k} com silhueta={best_silhouette}")

# Rodar K-means com o melhor K encontrado
kmeans_final = KMeans(n_clusters=best_k, random_state=42)
df['Cluster_KMeans'] = kmeans_final.fit_predict(X_scaled)
# Out:
# C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# K=4, Silhueta=0.15138021478826602
# C:\Users\paulo.rogerio\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 10
#       8 kmeans = KMeans(n_clusters=k, random_state=42)
#       9 cluster_labels = kmeans.fit_predict(X_scaled)
# ---> 10 silhouette_avg = silhouette_score(X_scaled, cluster_labels)
#      11 print(f"K={k}, Silhueta={silhouette_avg}")
#      12 if silhouette_avg > best_silhouette:
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:117, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115     else:
#     116         X, labels = X[indices], labels[indices]
# --> 117 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:237, in silhouette_samples(X, labels, metric, **kwds)
#     233 kwds["metric"] = metric
#     234 reduce_func = functools.partial(
#     235     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     236 )
# --> 237 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     238 intra_clust_dists, inter_clust_dists = results
#     239 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\pairwise.py:1867, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1865 else:
#    1866     X_chunk = X[sl]
# -> 1867 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1868 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1869     metric, None
#    1870 ) is euclidean_distances:
#    1871     # zeroing diagonal, taking care of aliases of "euclidean",
#    1872     # i.e. "l2"
#    1873     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
#    1581 # enforce a threading backend to prevent data communication overhead
#    1582 fd = delayed(_dist_wrapper)
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\pairwise.py:328, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     322     if Y_norm_squared.shape != (1, Y.shape[0]):
#     323         raise ValueError(
#     324             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     325             f"Y_norm_squared of shape {original_shape}."
#     326         )
# --> 328 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\metrics\pairwise.py:361, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     359         YY = None
#     360     else:
# --> 361         YY = row_norms(Y, squared=True)[np.newaxis, :]
#     363 if X.dtype == np.float32:
#     364     # To minimize precision issues with float32, we compute the distance
#     365     # matrix on chunks of X and Y upcast to float64
#     366     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\sklearn\utils\extmath.py:77, in row_norms(X, squared)
#      75     norms = csr_row_norms(X)
#      76 else:
# ---> 77     norms = np.einsum("ij,ij->i", X, X)
#      79 if not squared:
#      80     np.sqrt(norms, norms)
#
# File ~\AppData\Local\anaconda3\envs\sklearn_extra_env\lib\site-packages\numpy\core\einsumfunc.py:1371, in einsum(out, optimize, *operands, **kwargs)
#    1369     if specified_out:
#    1370         kwargs['out'] = out
# -> 1371     return c_einsum(*operands, **kwargs)
#    1373 # Check the kwargs to avoid a more cryptic error later, without having to
#    1374 # repeat default values here
#    1375 valid_einsum_kwargs = ['dtype', 'order', 'casting']
#
# KeyboardInterrupt:

# %%
# 4. Ajustar parâmetros do DBSCAN e avaliar silhueta
# DBSCAN não tem número fixo de clusters, mas podemos variar eps e min_samples
eps_values = [0.1, 0.2, 0.5, 1.0]  # Ajuste esses valores conforme seus dados
min_samples_values = [3, 5, 10]     # Ajuste também

best_dbscan_silhouette = -1
best_params = (None, None)

for eps in eps_values:
    for min_s in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_s)
        labels = dbscan.fit_predict(X_scaled)
        
        # DBSCAN pode atribuir rótulo -1 a ruídos. Se todos forem -1, silhueta é inviável
        # Silhueta só faz sentido se houver mais de um cluster válido
        if len(set(labels)) > 1 and -1 not in set(labels):
            sil = silhouette_score(X_scaled, labels)
            print(f"DBSCAN (eps={eps}, min_samples={min_s}) Silhueta={sil}")
            if sil > best_dbscan_silhouette:
                best_dbscan_silhouette = sil
                best_params = (eps, min_s)

if best_dbscan_silhouette > -1:
    print(f"Melhor configuração DBSCAN: eps={best_params[0]}, min_samples={best_params[1]}, silhueta={best_dbscan_silhouette}")
    # Rodar DBSCAN com a melhor configuração
    dbscan_final = DBSCAN(eps=best_params[0], min_samples=best_params[1])
    df['Cluster_DBSCAN'] = dbscan_final.fit_predict(X_scaled)
else:
    print("Não foi encontrada uma boa configuração DBSCAN que produza múltiplos clusters para cálculo de silhueta.")
